# %% [markdown]
# <a href="https://colab.research.google.com/github/halfbakedem/halfbakedem/blob/main/Copy_of_%5BWorld_Happiness%5D_Model_Submission_Guide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p align="center"><img width="50%" src="https://aimodelsharecontent.s3.amazonaws.com/aimodshare_banner.jpg" /></p>
#
#
# ---

# %% [markdown]
# ## Model Submission Guide: World Happiness Classification Competition
# Let's share our models to a centralized leaderboard, so that we can collaborate and learn from the model experimentation process...
#
# **Instructions:**
# 1.   Get data in and set up X_train / X_test / y_train
# 2.   Preprocess data using Sklearn Column Transformer/ Write and Save Preprocessor function
# 3. Fit model on preprocessed data and save preprocessor function and model
# 4. Generate predictions from X_test data and submit model to competition
# 5. Repeat submission process to improve place on leaderboard

# %% [markdown]
# ## 1. Get data in and set up X_train, X_test, y_train objects

# %%
#install aimodelshare library
! pip install aimodelshare --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: aimodelshare in /usr/local/lib/python3.8/dist-packages (0.0.178)
# Requirement already satisfied: onnx==1.12.0 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (1.12.0)
# Requirement already satisfied: onnxruntime>=1.7.0 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (1.13.1)
# Requirement already satisfied: docker==5.0.0 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (5.0.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (2022.6.2)
# Requirement already satisfied: PyJWT>=2.4.0 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (2.6.0)
# Requirement already satisfied: shortuuid>=1.0.8 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (1.0.11)
# Requirement already satisfied: boto3==1.21.20 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (1.21.20)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (1.13.1+cu116)
# Requirement already satisfied: scikit-learn==0.24.2 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (0.24.2)
# Requirement already satisfied: tf2onnx in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (1.13.0)
# Requirement already satisfied: onnxmltools>=1.6.1 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (1.11.1)
# Requirement already satisfied: seaborn>=0.11.2 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (0.11.2)
# Requirement already satisfied: importlib-resources==5.10.0 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (5.10.0)
# Requirement already satisfied: onnxconverter-common>=1.7.0 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (1.13.0)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (1.6.3)
# Requirement already satisfied: botocore==1.24.20 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (1.24.20)
# Requirement already satisfied: wget==3.2 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (3.2)
# Requirement already satisfied: skl2onnx>=1.8.0 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (1.13)
# Requirement already satisfied: keras2onnx>=1.7.0 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (1.7.0)
# Requirement already satisfied: tensorflow==2.9.2 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (2.9.2)
# Requirement already satisfied: pydot==1.3.0 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (1.3.0)
# Requirement already satisfied: pathlib>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (1.0.1)
# Requirement already satisfied: Pympler==0.9 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (0.9)
# Requirement already satisfied: psutil>=5.9.1 in /usr/local/lib/python3.8/dist-packages (from aimodelshare) (5.9.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse==1.6.3->aimodelshare) (0.38.4)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.8/dist-packages (from astunparse==1.6.3->aimodelshare) (1.15.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /usr/local/lib/python3.8/dist-packages (from boto3==1.21.20->aimodelshare) (0.5.2)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.8/dist-packages (from boto3==1.21.20->aimodelshare) (0.10.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.8/dist-packages (from botocore==1.24.20->aimodelshare) (1.26.14)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.8/dist-packages (from botocore==1.24.20->aimodelshare) (2.8.2)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.8/dist-packages (from docker==5.0.0->aimodelshare) (1.5.0)
# Requirement already satisfied: requests!=2.18.0,>=2.14.2 in /usr/local/lib/python3.8/dist-packages (from docker==5.0.0->aimodelshare) (2.25.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources==5.10.0->aimodelshare) (3.11.0)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.8/dist-packages (from onnx==1.12.0->aimodelshare) (1.21.6)
# Requirement already satisfied: protobuf<=3.20.1,>=3.12.2 in /usr/local/lib/python3.8/dist-packages (from onnx==1.12.0->aimodelshare) (3.19.6)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.8/dist-packages (from onnx==1.12.0->aimodelshare) (4.4.0)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.8/dist-packages (from pydot==1.3.0->aimodelshare) (3.0.9)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn==0.24.2->aimodelshare) (1.2.0)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.8/dist-packages (from scikit-learn==0.24.2->aimodelshare) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn==0.24.2->aimodelshare) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (1.14.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (57.4.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (3.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (2.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (3.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (0.29.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (15.0.6.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (0.2.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (2.9.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (2.9.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (1.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (21.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (1.51.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (1.1.2)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (2.9.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (1.3.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.9.2->aimodelshare) (0.4.0)
# Requirement already satisfied: fire in /usr/local/lib/python3.8/dist-packages (from keras2onnx>=1.7.0->aimodelshare) (0.5.0)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.8/dist-packages (from onnxruntime>=1.7.0->aimodelshare) (15.0.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.8/dist-packages (from onnxruntime>=1.7.0->aimodelshare) (1.7.1)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.8/dist-packages (from seaborn>=0.11.2->aimodelshare) (1.3.5)
# Requirement already satisfied: matplotlib>=2.2 in /usr/local/lib/python3.8/dist-packages (from seaborn>=0.11.2->aimodelshare) (3.2.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=2.2->seaborn>=0.11.2->aimodelshare) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=2.2->seaborn>=0.11.2->aimodelshare) (1.4.4)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.23->seaborn>=0.11.2->aimodelshare) (2022.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (4.0.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (1.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (2.16.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.4.6)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.8/dist-packages (from coloredlogs->onnxruntime>=1.7.0->aimodelshare) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.8/dist-packages (from sympy->onnxruntime>=1.7.0->aimodelshare) (1.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (5.2.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (6.0.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (3.2.2)

# %%
#Get competition data from course folder and unzip
# importing the zipfile module
from zipfile import ZipFile
  
# loading the temp.zip and creating a zip object
with ZipFile("world_happiness_competition_data.zip", 'r') as zObject:
  
    # Extracting all the members of the zip 
    # into a specific location.
    zObject.extractall()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load data
import pandas as pd
X_train = pd.read_csv('world_happiness_competition_data/X_train.csv')
X_test = pd.read_csv('world_happiness_competition_data/X_test.csv')
y_train = pd.read_csv('world_happiness_competition_data/y_train.csv')
y_train_labels = y_train.idxmax(axis=1)

X_train.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0              Peru           0.960           1.274                    0.854
# 1         Nicaragua           0.694           1.325                    0.835
# 2            Greece           1.181           1.156                    0.999
# 3             Qatar           1.684           1.313                    0.871
# 4        Uzbekistan           0.745           1.529                    0.756
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.455       0.083                      0.027
# 1                         0.435       0.200                      0.127
# 2                         0.067       0.000                      0.034
# 3                         0.555       0.220                      0.167
# 4                         0.631       0.322                      0.240
#
#          name    region                       sub-region  Terrorist_attacks
# 0        Peru  Americas  Latin America and the Caribbean          18.000000
# 1   Nicaragua  Americas  Latin America and the Caribbean         125.611111
# 2      Greece    Europe                  Southern Europe         112.000000
# 3       Qatar      Asia                     Western Asia          57.333333
# 4  Uzbekistan      Asia                     Central Asia         125.611111

# %% [markdown]
# ##2.   Preprocess data using Sklearn Column Transformer/ Write and Save Preprocessor function

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# We create the preprocessing pipelines for both numeric and categorical data.

numeric_features = X_train.drop(['Country or region', 'name', 'region', 'sub-region'], axis=1)
numeric_features=numeric_features.columns.tolist()

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

categorical_features = ['region', 'sub-region']

#Replacing missing values with Modal value and then one hot encoding.
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# final preprocessor object set up with ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

#Fit your preprocessor object
preprocess=preprocessor.fit(X_train)

# %%
# Write function to transform data with preprocessor

def preprocessor(data):
    data.drop(['Country or region', 'name'], axis=1)
    preprocessed_data=preprocess.transform(data)
    return preprocessed_data

# %%
# check shape of X data after preprocessing it using our new function
preprocessor(X_train).shape
# Out:
# (88, 26)

# %% [markdown]
# ##3. Fit model on preprocessed data and save preprocessor function and model

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=300, max_depth=3)
model.fit(preprocessor(X_train), y_train_labels) # Fitting to the training set.
model.score(preprocessor(X_train), y_train_labels) # Fit score, 0-1 scale.
# Out:
# 0.8522727272727273

# %% [markdown]
# #### Save preprocessor function to local "preprocessor.zip" file

# %%
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %% [markdown]
# #### Save model to local ".onnx" file

# %%
# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

# Check how many preprocessed input features are there?
from skl2onnx.common.data_types import FloatTensorType

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  #Insert correct number of preprocessed features

onnx_model = model_to_onnx(model, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %% [markdown]
# ## 4. Generate predictions from X_test data and submit model to competition

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials

#This is the unique rest api that powers this World Happiness Classification Playground -- make sure to update the apiurl for new competition deployments
apiurl="https://e2w6gh3id1.execute-api.us-east-2.amazonaws.com/prod/m"

set_credentials(apiurl=apiurl)
# Out:
# AI Modelshare Username:··········
# AI Modelshare Password:··········
# AI Model Share login credentials set successfully.

# %%
#Instantiate Competition
import aimodelshare as ai
mycompetition= ai.Competition(apiurl)

# %%
#Submit Model 1: 

#-- Generate predicted values (Model 1)
prediction_labels = model.predict(preprocessor(X_test))

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels,
                           custom_metadata={"team":"5"})
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 65
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:3164

# %%
# Get leaderboard to explore current best model architectures

# Get raw data in pandas data frame
data = mycompetition.get_leaderboard()

# Stylize leaderboard data
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_c8eb3_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 58.8%, transparent 58.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c8eb3_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 57.7%, transparent 57.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c8eb3_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 65.6%, transparent 65.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c8eb3_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 59.5%, transparent 59.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c8eb3_row0_col4, #T_c8eb3_row0_col5, #T_c8eb3_row0_col6, #T_c8eb3_row0_col7, #T_c8eb3_row0_col8, #T_c8eb3_row0_col9, #T_c8eb3_row0_col10, #T_c8eb3_row0_col11, #T_c8eb3_row0_col12, #T_c8eb3_row0_col13, #T_c8eb3_row0_col14, #T_c8eb3_row0_col15, #T_c8eb3_row0_col16, #T_c8eb3_row0_col17, #T_c8eb3_row0_col18, #T_c8eb3_row1_col4, #T_c8eb3_row1_col5, #T_c8eb3_row1_col6, #T_c8eb3_row1_col7, #T_c8eb3_row1_col8, #T_c8eb3_row1_col9, #T_c8eb3_row1_col10, #T_c8eb3_row1_col11, #T_c8eb3_row1_col12, #T_c8eb3_row1_col13, #T_c8eb3_row1_col14, #T_c8eb3_row1_col15, #T_c8eb3_row1_col16, #T_c8eb3_row1_col17, #T_c8eb3_row1_col18, #T_c8eb3_row2_col4, #T_c8eb3_row2_col5, #T_c8eb3_row2_col6, #T_c8eb3_row2_col7, #T_c8eb3_row2_col8, #T_c8eb3_row2_col9, #T_c8eb3_row2_col10, #T_c8eb3_row2_col11, #T_c8eb3_row2_col12, #T_c8eb3_row2_col13, #T_c8eb3_row2_col14, #T_c8eb3_row2_col15, #T_c8eb3_row2_col16, #T_c8eb3_row2_col17, #T_c8eb3_row2_col18, #T_c8eb3_row3_col4, #T_c8eb3_row3_col5, #T_c8eb3_row3_col6, #T_c8eb3_row3_col7, #T_c8eb3_row3_col8, #T_c8eb3_row3_col9, #T_c8eb3_row3_col10, #T_c8eb3_row3_col11, #T_c8eb3_row3_col12, #T_c8eb3_row3_col13, #T_c8eb3_row3_col14, #T_c8eb3_row3_col15, #T_c8eb3_row3_col16, #T_c8eb3_row3_col17, #T_c8eb3_row3_col18, #T_c8eb3_row4_col4, #T_c8eb3_row4_col5, #T_c8eb3_row4_col6, #T_c8eb3_row4_col7, #T_c8eb3_row4_col8, #T_c8eb3_row4_col9, #T_c8eb3_row4_col10, #T_c8eb3_row4_col11, #T_c8eb3_row4_col12, #T_c8eb3_row4_col13, #T_c8eb3_row4_col14, #T_c8eb3_row4_col15, #T_c8eb3_row4_col16, #T_c8eb3_row4_col17, #T_c8eb3_row4_col18, #T_c8eb3_row5_col4, #T_c8eb3_row5_col5, #T_c8eb3_row5_col6, #T_c8eb3_row5_col7, #T_c8eb3_row5_col8, #T_c8eb3_row5_col9, #T_c8eb3_row5_col10, #T_c8eb3_row5_col11, #T_c8eb3_row5_col12, #T_c8eb3_row5_col13, #T_c8eb3_row5_col14, #T_c8eb3_row5_col15, #T_c8eb3_row5_col16, #T_c8eb3_row5_col17, #T_c8eb3_row5_col18, #T_c8eb3_row6_col4, #T_c8eb3_row6_col5, #T_c8eb3_row6_col6, #T_c8eb3_row6_col7, #T_c8eb3_row6_col8, #T_c8eb3_row6_col9, #T_c8eb3_row6_col10, #T_c8eb3_row6_col11, #T_c8eb3_row6_col12, #T_c8eb3_row6_col13, #T_c8eb3_row6_col14, #T_c8eb3_row6_col15, #T_c8eb3_row6_col16, #T_c8eb3_row6_col17, #T_c8eb3_row6_col18, #T_c8eb3_row7_col4, #T_c8eb3_row7_col5, #T_c8eb3_row7_col6, #T_c8eb3_row7_col7, #T_c8eb3_row7_col8, #T_c8eb3_row7_col9, #T_c8eb3_row7_col10, #T_c8eb3_row7_col11, #T_c8eb3_row7_col12, #T_c8eb3_row7_col13, #T_c8eb3_row7_col14, #T_c8eb3_row7_col15, #T_c8eb3_row7_col16, #T_c8eb3_row7_col17, #T_c8eb3_row7_col18, #T_c8eb3_row8_col4, #T_c8eb3_row8_col5, #T_c8eb3_row8_col6, #T_c8eb3_row8_col7, #T_c8eb3_row8_col8, #T_c8eb3_row8_col9, #T_c8eb3_row8_col10, #T_c8eb3_row8_col11, #T_c8eb3_row8_col12, #T_c8eb3_row8_col13, #T_c8eb3_row8_col14, #T_c8eb3_row8_col15, #T_c8eb3_row8_col16, #T_c8eb3_row8_col17, #T_c8eb3_row8_col18, #T_c8eb3_row9_col4, #T_c8eb3_row9_col5, #T_c8eb3_row9_col6, #T_c8eb3_row9_col7, #T_c8eb3_row9_col8, #T_c8eb3_row9_col9, #T_c8eb3_row9_col10, #T_c8eb3_row9_col11, #T_c8eb3_row9_col12, #T_c8eb3_row9_col13, #T_c8eb3_row9_col14, #T_c8eb3_row9_col15, #T_c8eb3_row9_col16, #T_c8eb3_row9_col17, #T_c8eb3_row9_col18, #T_c8eb3_row10_col4, #T_c8eb3_row10_col5, #T_c8eb3_row10_col6, #T_c8eb3_row10_col7, #T_c8eb3_row10_col8, #T_c8eb3_row10_col9, #T_c8eb3_row10_col10, #T_c8eb3_row10_col11, #T_c8eb3_row10_col12, #T_c8eb3_row10_col13, #T_c8eb3_row10_col14, #T_c8eb3_row10_col15, #T_c8eb3_row10_col16, #T_c8eb3_row10_col17, #T_c8eb3_row10_col18, #T_c8eb3_row11_col4, #T_c8eb3_row11_col5, #T_c8eb3_row11_col6, #T_c8eb3_row11_col7, #T_c8eb3_row11_col8, #T_c8eb3_row11_col9, #T_c8eb3_row11_col10, #T_c8eb3_row11_col11, #T_c8eb3_row11_col12, #T_c8eb3_row11_col13, #T_c8eb3_row11_col14, #T_c8eb3_row11_col15, #T_c8eb3_row11_col16, #T_c8eb3_row11_col17, #T_c8eb3_row11_col18, #T_c8eb3_row12_col4, #T_c8eb3_row12_col5, #T_c8eb3_row12_col6, #T_c8eb3_row12_col7, #T_c8eb3_row12_col8, #T_c8eb3_row12_col9, #T_c8eb3_row12_col10, #T_c8eb3_row12_col11, #T_c8eb3_row12_col12, #T_c8eb3_row12_col13, #T_c8eb3_row12_col14, #T_c8eb3_row12_col15, #T_c ...

# %% [markdown]
# ## 5. Repeat submission process to improve place on leaderboard

# %%
# Train and submit model 2 using same preprocessor (note that you could save a new preprocessor, but we will use the same one for this example).
from sklearn.ensemble import RandomForestClassifier

model_2 = RandomForestClassifier(n_estimators=100, max_depth=5)
model_2.fit(preprocessor(X_train), y_train_labels) # Fitting to the training set.
model_2.score(preprocessor(X_train), y_train_labels) # Fit score, 0-1 scale.
# Out:
# 0.9545454545454546

# %%
# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  # Insert correct number of preprocessed features

onnx_model = model_to_onnx(model_2, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("model2.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 2: 

#-- Generate predicted y values (Model 2)
prediction_labels = model_2.predict(preprocessor(X_test))

# Submit Model 2 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model2.onnx",
                                 prediction_submission=prediction_labels,
                                 preprocessor_filepath="preprocessor.zip")
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 3
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:3164

# %%
# Compare two or more models
data=mycompetition.compare_models([2,3], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_68222_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_68222_row4_col2, #T_68222_row4_col3, #T_68222_row13_col2 {
#   background: tomato;
# }
# </style>
# <table id="T_68222_">
#   <caption>Model type: RandomForestClassifier</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >param_name</th>
#       <th class="col_heading level0 col1" >default_value</th>
#       <th class="col_heading level0 col2" >model_version_2</th>
#       <th class="col_heading level0 col3" >model_version_3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68222_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_68222_row0_col0" class="data row0 col0" >bootstrap</td>
#       <td id="T_68222_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_68222_row0_col2" class="data row0 col2" >True</td>
#       <td id="T_68222_row0_col3" class="data row0 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_68222_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_68222_row1_col0" class="data row1 col0" >ccp_alpha</td>
#       <td id="T_68222_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_68222_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_68222_row1_col3" class="data row1 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_68222_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_68222_row2_col0" class="data row2 col0" >class_weight</td>
#       <td id="T_68222_row2_col1" class="data row2 col1" >None</td>
#       <td id="T_68222_row2_col2" class="data row2 col2" >None</td>
#       <td id="T_68222_row2_col3" class="data row2 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_68222_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_68222_row3_col0" class="data row3 col0" >criterion</td>
#       <td id="T_68222_row3_col1" class="data row3 col1" >gini</td>
#       <td id="T_68222_row3_col2" class="data row3 col2" >gini</td>
#       <td id="T_68222_row3_col3" class="data row3 col3" >gini</td>
#     </tr>
#     <tr>
#       <th id="T_68222_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_68222_row4_col0" class="data row4 col0" >max_depth</td>
#       <td id="T_68222_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_68222_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_68222_row4_col3" class="data row4 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_68222_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_68222_row5_col0" class="data row5 col0" >max_features</td>
#       <td id="T_68222_row5_col1" class="data row5 col1" >auto</td>
#       <td id="T_68222_row5_col2" class="data row5 col2" >auto</td>
#       <td id="T_68222_row5_col3" class="data row5 col3" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_68222_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_68222_row6_col0" class="data row6 col0" >max_leaf_nodes</td>
#       <td id="T_68222_row6_col1" class="data row6 col1" >None</td>
#       <td id="T_68222_row6_col2" class="data row6 col2" >None</td>
#       <td id="T_68222_row6_col3" class="data row6 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_68222_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_68222_row7_col0" class="data row7 col0" >max_samples</td>
#       <td id="T_68222_row7_col1" class="data row7 col1" >None</td>
#       <td id="T_68222_row7_col2" class="data row7 col2" >None</td>
#       <td id="T_68222_row7_col3" class="data row7 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_68222_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_68222_row8_col0" class="data row8 col0" >min_impurity_decrease</td>
#       <td id="T_68222_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_68222_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_68222_row8_col3" class="data row8 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_68222_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_68222_row9_col0" class="data row9 col0" >min_impurity_split</td>
#       <td id="T_68222_row9_col1" class="data row9 col1" >None</td>
#       <td id="T_68222_row9_col2" class="data row9 col2" >None</td>
#       <td id="T_68222_row9_col3" class="data row9 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_68222_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_68222_row10_col0" class="data row10 col0" >min_samples_leaf</td>
#       <td id="T_68222_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_68222_row10_col2" class="data row10 col2" >1</td>
#       <td id="T_68222_row10_col3" class="data row10 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_68222_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_68222_row11_col0" class="data row11 col0" >min_samples_split</td>
#       <td id="T_68222_row11_col1" class="data row11 col1" >2</td>
#       <td id="T_68222_row11_col2" class="data row11 col2" >2</td>
#       <td id="T_68222_row11_col3" class="data row11 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_68222_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_68222_row12_col0" class="data row12 col0" >min_weight_fraction_leaf</td>
#       <td id="T_68222_row12_col1" class="data row12 col1" >0.000000</td>
#       <td id="T_68222_row12_col2" class="data row12 col2" >0.000000</td>
#       <td id="T_68222_row12_col3" class="data row12 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_68222_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_68222_row13_col0" class="data row13 col0" >n_estimators</td>
#       <td id="T_68222_row13_col1" class="data row13 col1" >100</td>
#       <td id="T_68222_row13_col2" class="data row13 col2" >300</td>
#       <td id="T_68222_row13_col3" class="data row13 col3" >100</td>
#     </tr>
#     <tr>
#       <th id="T_68222_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_68222_row14_col0" class="data row14 col0" >n_jobs</td>
#       <td id="T_68222_row14_col1" class="data row14 col1" >None</td>
#       <td id="T_68222_row14_col2" class="data row14 col2" >None</td>
#       <td id="T_68222_row14_col3" class="data row14 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_68222_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_68222_row15_col0" class="data row15 col0" >oob_score</td>
#       <td id="T_68222_row15_col1" class="data row15 col1" >False</td>
#       <td id="T_68222_row15_col2" class="data row15 col2" >False</td>
#       <td id="T_68222_row15_col3" class="data row15 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_68222_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_68222_row16_col0" class="data row16 col0" >random_state</td>
#       <td id="T_68222_row16_col1" class="data row16 col1" >None</td>
#       <td id="T_68222_row16_col2" class="data row16 col2" >None</td>
#       <td id="T_68222_row16_col3" class="data row16 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_68222_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_68222_row17_col0" class="data row17 col0" >verbose</td>
#       <td id="T_68222_row17_col1" class="data row17 col1" >0</td>
#       <td id="T_68222_row17_col2" class="data row17 col2" >0</td>
#       <td id="T_68222_row17_col3" class="data row17 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_68222_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_68222_row18_col0" class="data row18 col0" >warm_start</td>
#       <td id="T_68222_row18_col1" class="data row18 col1" >False</td>
#       <td id="T_68222_row18_col2" class="data row18 col2" >False</td>
#       <td id="T_68222_row18_col3" class="data row18 col3" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Submit a third model using GridSearchCV

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
import numpy as np

param_grid = {'n_estimators': np.arange(100, 300, 500),'max_depth':[1, 3, 5]} #np.arange creates sequence of numbers for each k value

gridmodel = GridSearchCV(RandomForestClassifier(), param_grid=param_grid, cv=10)

#use meta model methods to fit score and predict model:
gridmodel.fit(preprocessor(X_train), y_train_labels)

#extract best score and parameter by calling objects "best_score_" and "best_params_"
print("best mean cross-validation score: {:.3f}".format(gridmodel.best_score_))
print("best parameters: {}".format(gridmodel.best_params_))
# Out:
# best mean cross-validation score: 0.668
# best parameters: {'max_depth': 5, 'n_estimators': 100}

# %%
# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  # Insert correct number of preprocessed features

onnx_model = model_to_onnx(gridmodel, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("gridmodel.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 3: 

#-- Generate predicted values
prediction_labels = gridmodel.predict(preprocessor(X_test))

# Submit to Competition Leaderboard
mycompetition.submit_model(model_filepath = "gridmodel.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 4
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:3164

# %%
# Get leaderboard

data = mycompetition.get_leaderboard()
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_3b5a3_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 50.0%, transparent 50.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_3b5a3_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 47.6%, transparent 47.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_3b5a3_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 67.7%, transparent 67.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_3b5a3_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 52.4%, transparent 52.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_3b5a3_row0_col4, #T_3b5a3_row0_col5, #T_3b5a3_row0_col6, #T_3b5a3_row0_col7, #T_3b5a3_row0_col8, #T_3b5a3_row0_col9, #T_3b5a3_row0_col10, #T_3b5a3_row0_col11, #T_3b5a3_row0_col12, #T_3b5a3_row0_col13, #T_3b5a3_row0_col14, #T_3b5a3_row0_col15, #T_3b5a3_row0_col16, #T_3b5a3_row0_col17, #T_3b5a3_row1_col4, #T_3b5a3_row1_col5, #T_3b5a3_row1_col6, #T_3b5a3_row1_col7, #T_3b5a3_row1_col8, #T_3b5a3_row1_col9, #T_3b5a3_row1_col10, #T_3b5a3_row1_col11, #T_3b5a3_row1_col12, #T_3b5a3_row1_col13, #T_3b5a3_row1_col14, #T_3b5a3_row1_col15, #T_3b5a3_row1_col16, #T_3b5a3_row1_col17, #T_3b5a3_row2_col4, #T_3b5a3_row2_col5, #T_3b5a3_row2_col6, #T_3b5a3_row2_col7, #T_3b5a3_row2_col8, #T_3b5a3_row2_col9, #T_3b5a3_row2_col10, #T_3b5a3_row2_col11, #T_3b5a3_row2_col12, #T_3b5a3_row2_col13, #T_3b5a3_row2_col14, #T_3b5a3_row2_col15, #T_3b5a3_row2_col16, #T_3b5a3_row2_col17, #T_3b5a3_row3_col4, #T_3b5a3_row3_col5, #T_3b5a3_row3_col6, #T_3b5a3_row3_col7, #T_3b5a3_row3_col8, #T_3b5a3_row3_col9, #T_3b5a3_row3_col10, #T_3b5a3_row3_col11, #T_3b5a3_row3_col12, #T_3b5a3_row3_col13, #T_3b5a3_row3_col14, #T_3b5a3_row3_col15, #T_3b5a3_row3_col16, #T_3b5a3_row3_col17 {
#   text-align: center;
# }
# #T_3b5a3_row1_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 47.1%, transparent 47.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_3b5a3_row1_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 44.1%, transparent 44.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_3b5a3_row1_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 64.4%, transparent 64.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_3b5a3_row1_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 49.6%, transparent 49.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_3b5a3_row2_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 44.1%, transparent 44.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_3b5a3_row2_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 39.3%, transparent 39.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_3b5a3_row2_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 51.1%, transparent 51.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_3b5a3_row2_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 46.7%, transparent 46.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_3b5a3_row3_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 41.2%, transparent 41.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_3b5a3_row3_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 30.4%, transparent 30.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_3b5a3_row3_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 30.0%, transparent 30.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_3b5a3_row3_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 45.0%, transparent 45.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# </style>
# <table id="T_3b5a3_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >accuracy</th>
#       <th class="col_heading level0 col1" >f1_score</th>
#       <th class="col_heading level0 col2" >precision</th>
#       <th class="col_heading level0 col3" >recall</th>
#       <th class="col_heading level0 col4" >ml_framework</th>
#       <th class="col_heading level0 col5" >transfer_learning</th>
#       <th class="col_heading level0 col6" >deep_learning</th>
#       <th class="col_heading level0 col7" >model_type</th>
#       <th class="col_heading level0 col8" >depth</th>
#       <th class="col_heading level0 col9" >num_params</th>
#       <th class="col_heading level0 col10" >dense_layers</th>
#       <th class="col_heading level0 col11" >relu_act</th>
#       <th class="col_heading level0 col12" >softmax_act</th>
#       <th class="col_heading level0 col13" >loss</th>
#       <th class="col_heading level0 col14" >optimizer</th>
#       <th class="col_heading level0 col15" >memory_size</th>
#       <th class="col_heading level0 col16" >username</th>
#       <th class="col_heading level0 col17" >version</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b5a3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3b5a3_row0_col0" class="data row0 col0" >50.00%</td>
#       <td id="T_3b5a3_row0_col1" class="data row0 col1" >47.62%</td>
#       <td id="T_3b5a3_row0_col2" class="data row0 col2" >67.73%</td>
#       <td id="T_3b5a3_row0_col3" class="data row0 col3" >52.43%</td>
#       <td id="T_3b5a3_row0_col4" class="data row0 col4" >sklearn</td>
#       <td id="T_3b5a3_row0_col5" class="data row0 col5" >False</td>
#       <td id="T_3b5a3_row0_col6" class="data row0 col6" >False</td>
#       <td id="T_3b5a3_row0_col7" class="data row0 col7" >RandomForestClassifier</td>
#       <td id="T_3b5a3_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_3b5a3_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_3b5a3_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_3b5a3_row0_col11" class="data row0 col11" >nan</td>
#       <td id="T_3b5a3_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_3b5a3_row0_col13" class="data row0 col13" >nan</td>
#       <td id="T_3b5a3_row0_col14" class="data row0 col14" >nan</td>
#       <td id="T_3b5a3_row0_col15" class="data row0 col15" >nan</td>
#       <td id="T_3b5a3_row0_col16" class="data row0 col16" >newusertest</td>
#       <td id="T_3b5a3_row0_col17" class="data row0 col17" >3</td>
#     </tr>
#     <tr>
#       <th id="T_3b5a3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3b5a3_row1_col0" class="data row1 col0" >47.06%</td>
#       <td id="T_3b5a3_row1_col1" class="data row1 col1" >44.06%</td>
#       <td id="T_3b5a3_row1_col2" class="data row1 col2" >64.39%</td>
#       <td id="T_3b5a3_row1_col3" class="data row1 col3" >49.57%</td>
#       <td id="T_3b5a3_row1_col4" class="data row1 col4" >sklearn</td>
#       <td id="T_3b5a3_row1_col5" class="data row1 col5" >False</td>
#       <td id="T_3b5a3_row1_col6" class="data row1 col6" >False</td>
#       <td id="T_3b5a3_row1_col7" class="data row1 col7" >RandomForestClassifier</td>
#       <td id="T_3b5a3_row1_col8" class="data row1 col8" >nan</td>
#       <td id="T_3b5a3_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_3b5a3_row1_col10" class="data row1 col10" >nan</td>
#       <td id="T_3b5a3_row1_col11" class="data row1 col11" >nan</td>
#       <td id="T_3b5a3_row1_col12" class="data row1 col12" >nan</td>
#       <td id="T_3b5a3_row1_col13" class="data row1 col13" >nan</td>
#       <td id="T_3b5a3_row1_col14" class="data row1 col14" >nan</td>
#       <td id="T_3b5a3_row1_col15" class="data row1 col15" >nan</td>
#       <td id="T_3b5a3_row1_col16" class="data row1 col16" >newusertest</td>
#       <td id="T_3b5a3_row1_col17" class="data row1 col17" >4

# %%
# Compare two or more models
data=mycompetition.compare_models([3,4], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_3a9b2_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_3a9b2_row4_col2, #T_3a9b2_row4_col3 {
#   background: tomato;
# }
# </style>
# <table id="T_3a9b2_">
#   <caption>Model type: RandomForestClassifier</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >param_name</th>
#       <th class="col_heading level0 col1" >default_value</th>
#       <th class="col_heading level0 col2" >model_version_3</th>
#       <th class="col_heading level0 col3" >model_version_4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a9b2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3a9b2_row0_col0" class="data row0 col0" >bootstrap</td>
#       <td id="T_3a9b2_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_3a9b2_row0_col2" class="data row0 col2" >True</td>
#       <td id="T_3a9b2_row0_col3" class="data row0 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3a9b2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3a9b2_row1_col0" class="data row1 col0" >ccp_alpha</td>
#       <td id="T_3a9b2_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_3a9b2_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_3a9b2_row1_col3" class="data row1 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3a9b2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3a9b2_row2_col0" class="data row2 col0" >class_weight</td>
#       <td id="T_3a9b2_row2_col1" class="data row2 col1" >None</td>
#       <td id="T_3a9b2_row2_col2" class="data row2 col2" >None</td>
#       <td id="T_3a9b2_row2_col3" class="data row2 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3a9b2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3a9b2_row3_col0" class="data row3 col0" >criterion</td>
#       <td id="T_3a9b2_row3_col1" class="data row3 col1" >gini</td>
#       <td id="T_3a9b2_row3_col2" class="data row3 col2" >gini</td>
#       <td id="T_3a9b2_row3_col3" class="data row3 col3" >gini</td>
#     </tr>
#     <tr>
#       <th id="T_3a9b2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3a9b2_row4_col0" class="data row4 col0" >max_depth</td>
#       <td id="T_3a9b2_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_3a9b2_row4_col2" class="data row4 col2" >5</td>
#       <td id="T_3a9b2_row4_col3" class="data row4 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_3a9b2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3a9b2_row5_col0" class="data row5 col0" >max_features</td>
#       <td id="T_3a9b2_row5_col1" class="data row5 col1" >auto</td>
#       <td id="T_3a9b2_row5_col2" class="data row5 col2" >auto</td>
#       <td id="T_3a9b2_row5_col3" class="data row5 col3" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_3a9b2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3a9b2_row6_col0" class="data row6 col0" >max_leaf_nodes</td>
#       <td id="T_3a9b2_row6_col1" class="data row6 col1" >None</td>
#       <td id="T_3a9b2_row6_col2" class="data row6 col2" >None</td>
#       <td id="T_3a9b2_row6_col3" class="data row6 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3a9b2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3a9b2_row7_col0" class="data row7 col0" >max_samples</td>
#       <td id="T_3a9b2_row7_col1" class="data row7 col1" >None</td>
#       <td id="T_3a9b2_row7_col2" class="data row7 col2" >None</td>
#       <td id="T_3a9b2_row7_col3" class="data row7 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3a9b2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3a9b2_row8_col0" class="data row8 col0" >min_impurity_decrease</td>
#       <td id="T_3a9b2_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_3a9b2_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_3a9b2_row8_col3" class="data row8 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3a9b2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3a9b2_row9_col0" class="data row9 col0" >min_impurity_split</td>
#       <td id="T_3a9b2_row9_col1" class="data row9 col1" >None</td>
#       <td id="T_3a9b2_row9_col2" class="data row9 col2" >None</td>
#       <td id="T_3a9b2_row9_col3" class="data row9 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3a9b2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3a9b2_row10_col0" class="data row10 col0" >min_samples_leaf</td>
#       <td id="T_3a9b2_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_3a9b2_row10_col2" class="data row10 col2" >1</td>
#       <td id="T_3a9b2_row10_col3" class="data row10 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3a9b2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3a9b2_row11_col0" class="data row11 col0" >min_samples_split</td>
#       <td id="T_3a9b2_row11_col1" class="data row11 col1" >2</td>
#       <td id="T_3a9b2_row11_col2" class="data row11 col2" >2</td>
#       <td id="T_3a9b2_row11_col3" class="data row11 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_3a9b2_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3a9b2_row12_col0" class="data row12 col0" >min_weight_fraction_leaf</td>
#       <td id="T_3a9b2_row12_col1" class="data row12 col1" >0.000000</td>
#       <td id="T_3a9b2_row12_col2" class="data row12 col2" >0.000000</td>
#       <td id="T_3a9b2_row12_col3" class="data row12 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3a9b2_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3a9b2_row13_col0" class="data row13 col0" >n_estimators</td>
#       <td id="T_3a9b2_row13_col1" class="data row13 col1" >100</td>
#       <td id="T_3a9b2_row13_col2" class="data row13 col2" >100</td>
#       <td id="T_3a9b2_row13_col3" class="data row13 col3" >100</td>
#     </tr>
#     <tr>
#       <th id="T_3a9b2_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3a9b2_row14_col0" class="data row14 col0" >n_jobs</td>
#       <td id="T_3a9b2_row14_col1" class="data row14 col1" >None</td>
#       <td id="T_3a9b2_row14_col2" class="data row14 col2" >None</td>
#       <td id="T_3a9b2_row14_col3" class="data row14 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3a9b2_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3a9b2_row15_col0" class="data row15 col0" >oob_score</td>
#       <td id="T_3a9b2_row15_col1" class="data row15 col1" >False</td>
#       <td id="T_3a9b2_row15_col2" class="data row15 col2" >False</td>
#       <td id="T_3a9b2_row15_col3" class="data row15 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3a9b2_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3a9b2_row16_col0" class="data row16 col0" >random_state</td>
#       <td id="T_3a9b2_row16_col1" class="data row16 col1" >None</td>
#       <td id="T_3a9b2_row16_col2" class="data row16 col2" >None</td>
#       <td id="T_3a9b2_row16_col3" class="data row16 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3a9b2_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_3a9b2_row17_col0" class="data row17 col0" >verbose</td>
#       <td id="T_3a9b2_row17_col1" class="data row17 col1" >0</td>
#       <td id="T_3a9b2_row17_col2" class="data row17 col2" >0</td>
#       <td id="T_3a9b2_row17_col3" class="data row17 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3a9b2_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_3a9b2_row18_col0" class="data row18 col0" >warm_start</td>
#       <td id="T_3a9b2_row18_col1" class="data row18 col1" >False</td>
#       <td id="T_3a9b2_row18_col2" class="data row18 col2" >False</td>
#       <td id="T_3a9b2_row18_col3" class="data row18 col3" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Here are several classic ML architectures you can consider choosing from to experiment with next:
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier

#Example code to fit model:
model = GradientBoostingClassifier(n_estimators=50, learning_rate=1.0,
    max_depth=1, random_state=0).fit(preprocessor(X_train), y_train_labels)
model.score(preprocessor(X_train), y_train_labels)

# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  # Insert correct number of preprocessed features

onnx_model = model_to_onnx(model, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

#-- Generate predicted values 
prediction_labels = model.predict(preprocessor(X_test))

# Submit model to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 5
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:3164

# %%
# Or you can experiment with deep learning models: 
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation

feature_count=preprocessor(X_train).shape[1] #count features in input data

keras_model = Sequential()
keras_model.add(Dense(128, input_dim=feature_count, activation='relu'))
keras_model.add(Dense(64, activation='relu'))
keras_model.add(Dense(64, activation='relu'))
keras_model.add(Dense(32, activation='relu'))

keras_model.add(Dense(5, activation='softmax')) 
                                            
# Compile model
keras_model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# Fitting the NN to the Training set
keras_model.fit(preprocessor(X_train), y_train, ## Note that keras models require a one-hot-encoded y_train object
               batch_size = 20, 
               epochs = 300, validation_split=0.25)

# %%
# Save keras model to ONNX file 

from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(keras_model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
# Submit keras model: 

#-- Generate predicted y values
#Note: Keras predict returns the predicted column index location for classification models
prediction_column_index=keras_model.predict(preprocessor(X_test)).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 6
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1289

# %%
# Check leaderboard 

data = mycompetition.get_leaderboard()
mycompetition.stylize_leaderboard(data)
# Out:
# <style  type="text/css" >
# #T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row0_col0{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f8d6 53.8%, transparent 53.8%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row0_col1{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#c778c8 53.6%, transparent 53.6%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row0_col2{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff4971 57.9%, transparent 57.9%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row0_col3{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#aadbaa 53.7%, transparent 53.7%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row0_col4,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row0_col5,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row0_col6,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row0_col7,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row0_col8,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row0_col9,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row0_col10,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row0_col11,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row0_col12,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row0_col13,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row0_col14,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row0_col15,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row0_col16,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row0_col17,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row0_col18,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row1_col4,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row1_col5,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row1_col6,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row1_col7,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row1_col8,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row1_col9,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row1_col10,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row1_col11,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row1_col12,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row1_col13,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row1_col14,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row1_col15,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row1_col16,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row1_col17,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row1_col18,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row2_col4,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row2_col5,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row2_col6,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row2_col7,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row2_col8,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row2_col9,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row2_col10,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row2_col11,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row2_col12,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row2_col13,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row2_col14,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row2_col15,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row2_col16,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row2_col17,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row2_col18,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row3_col4,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row3_col5,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row3_col6,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row3_col7,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row3_col8,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row3_col9,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row3_col10,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row3_col11,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row3_col12,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row3_col13,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row3_col14,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row3_col15,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row3_col16,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row3_col17,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row3_col18,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row4_col4,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row4_col5,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row4_col6,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row4_col7,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row4_col8,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row4_col9,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row4_col10,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row4_col11,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row4_col12,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row4_col13,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row4_col14,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row4_col15,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row4_col16,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row4_col17,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row4_col18,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row5_col4,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row5_col5,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row5_col6,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row5_col7,#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row5_col8,#T_0f90566a_7ed8_11ec_8c3a ...
#             text-align:  center;
#         }#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row1_col0{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f8d6 51.9%, transparent 51.9%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row1_col1{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#c778c8 51.4%, transparent 51.4%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row1_col2{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff4971 54.4%, transparent 54.4%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row1_col3{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#aadbaa 52.2%, transparent 52.2%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row2_col0{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f8d6 50.0%, transparent 50.0%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row2_col1{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#c778c8 50.1%, transparent 50.1%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row2_col2{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff4971 56.0%, transparent 56.0%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_0f90566a_7ed8_11ec_8c3a_0242ac1c0002row2_col3{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#aadbaa 50.8%, transparent 50.8%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_0f90566a_7ed8_11ec_8c3a_0242ac1c
